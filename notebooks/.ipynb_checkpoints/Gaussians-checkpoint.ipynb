# %%
import os, sys
cwd = os.getcwd()

api_path = os.path.join(cwd, '..', 'tools')
models_2d_path = os.path.join(cwd, '..', 'models_25gaussians', 'jensen_minimax')
models_5d_path = os.path.join(cwd, '..', 'models_5d_gaussians', 'jensen_minimax')
sys.path.append(api_path)

# %%
import numpy as np
import sklearn.datasets
import time
import random
import glob
from tqdm import tqdm

import pyro
from pyro.infer import MCMC, NUTS, HMC
from functools import partial
import ot

from matplotlib import pyplot as plt

import torch, torch.nn as nn
import torch.nn.functional as F

from torch.autograd import Variable
from torch import autograd
from torch.distributions import MultivariateNormal, Normal, Independent, Uniform

from utils import (Evolution,
                   prepare_25gaussian_data, 
                   prepare_swissroll_data,
                   prepare_gaussians,
                   prepare_train_batches,
                   prepare_dataloader,
                   logging)
from gan_fc_models import (Generator_fc, 
                           Discriminator_fc, 
                           weights_init_1, 
                           weights_init_2)
from visualization import (send_file_to_remote,
                           sample_fake_data,
                           plot_fake_data_mode,
                           plot_fake_data_projection,
                           discriminator_2d_visualization,
                           visualize_potential_energy,
                           mh_sampling_visualize,
                           langevin_sampling_visualize,
                           mala_sampling_visualize,
                           xtry_mala_sampling_visualize,
                           epoch_visualization)
from mh_sampling import mh_sampling
from ebm_sampling import (langevin_sampling, 
                          mala_sampling,
                          xtry_mala_sampling,
                          xtry_mala_dynamics,
                          xtry_mala_dynamics_v2,
                          Target,
                          Gaussian_mixture,
                          DotDict,
                          xtry_mala_dynamics_general)

# %% [markdown]
# # 2D Gaussians, GANs

# %%
from sklearn.preprocessing import StandardScaler
random_seed = 42
train_dataset_size = 64000
sigma = 0.05

torch.manual_seed(random_seed)
np.random.seed(random_seed)
random.seed(random_seed)

X_train, means = prepare_25gaussian_data(train_dataset_size,
                                         sigma, 
                                         random_seed)

scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train)

# %%
n_dim = 2
n_layers_g = 4
n_hid_g = 100
n_out = 2

n_layers_d = 4
n_hid_d = 100

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

G = Generator_fc(n_dim=n_dim, 
                 n_layers=n_layers_g,
                 n_hid=n_hid_g,
                 n_out=n_out,
                 non_linear=nn.ReLU(),
                 device=device)
D = Discriminator_fc(n_in=n_dim, 
                     n_layers=n_layers_d,
                     n_hid=n_hid_d,
                     non_linear=nn.ReLU(),
                     device=device)

# %%
discriminator_regexp = os.path.join(models_2d_path, "*_discriminator.pth")
generator_regexp = os.path.join(models_2d_path, "*_generator.pth")
discriminator_name = [f for f in glob.glob(discriminator_regexp)][0]
generator_name = [f for f in glob.glob(generator_regexp)][0]

# %%
G.load_state_dict(torch.load(generator_name))
D.load_state_dict(torch.load(discriminator_name))
# Out:
# <All keys matched successfully>

# %%
epoch = 1000
path_to_save = None
batch_size_sample = 5000

# %%
G = G.to(device)
D = D.to(device)

# %%
for p in D.parameters():  
    p.requires_grad = False
for p in G.parameters():  
    p.requires_grad = False

# %%
sample_fake_data(G, X_train, epoch, path_to_save, 
                 scaler = scaler,
                 batch_size_sample = batch_size_sample)

# %%
x_range = 3.0
y_range = 3.0
discriminator_2d_visualization(D,
                               x_range,
                               y_range,
                               path_to_save,
                               epoch,
                               scaler = scaler,
                               num_points = 700)

# %%
n_calib_pts = 10000
type_calibrator = 'iso'
normalize_to_0_1 = True
mh_sampling_visualize(G, 
                      D,
                      X_train, epoch, 
                      path_to_save,
                      n_calib_pts = n_calib_pts,
                      scaler = scaler, 
                      batch_size_sample = batch_size_sample,
                      type_calibrator = type_calibrator,
                      normalize_to_0_1 = normalize_to_0_1)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
# Start to do MH sampling....
# 100%|██████████| 5000/5000 [01:04<00:00, 77.52it/s]

# %%
alpha = 1.0
step_lr = 1e-3
eps_std = 1e-2
n_steps = 5000
n_batches = 1
langevin_sampling_visualize(G, 
                            D,
                            X_train,  
                            path_to_save,
                            alpha = alpha,
                            scaler = scaler, 
                            batch_size_sample = batch_size_sample,
                            path_to_save_remote = None,
                            port_to_remote = None,
                            step_lr = step_lr,
                            eps_std = eps_std,
                            n_steps = n_steps,
                            n_batches = n_batches)
# Out:
# 100%|██████████| 1/1 [00:07<00:00,  7.75s/it]

# %%
alpha = 1.0
step_lr = 1e-3
eps_std = 1e-2
n_steps = 5000
n_batches = 1
mala_sampling_visualize(G, 
                        D,
                        X_train,  
                        path_to_save,
                        alpha = alpha,
                        scaler = scaler, 
                        batch_size_sample = batch_size_sample,
                        path_to_save_remote = None,
                        port_to_remote = None,
                        step_lr = step_lr,
                        eps_std = eps_std,
                        n_steps = n_steps,
                        n_batches = n_batches)
# Out:
# 100%|██████████| 1/1 [00:41<00:00, 41.24s/it]

# %%
alpha = 1.0
step_lr = 1e-3
eps_std = 1e-2
n_steps = 50
n_batches = 1
mala_sampling_visualize(G, 
                        D,
                        X_train,  
                        path_to_save,
                        alpha = alpha,
                        scaler = scaler, 
                        batch_size_sample = batch_size_sample,
                        path_to_save_remote = None,
                        port_to_remote = None,
                        step_lr = step_lr,
                        eps_std = eps_std,
                        n_steps = n_steps,
                        n_batches = n_batches)
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  2.41it/s]

# %%
x_range = 3.0
y_range = 3.0
norm_grads = False
normalize_to_0_1 = True
path_to_save = None
visualize_potential_energy(D,
                           G,
                           x_range,
                           y_range,
                           path_to_save = path_to_save,
                           norm_grads = norm_grads,
                           normalize_to_0_1 = normalize_to_0_1,
                           num_points = 100)

# %%
x_range = 3.0
y_range = 3.0
norm_grads = True
normalize_to_0_1 = True
visualize_potential_energy(D,
                           G,
                           x_range,
                           y_range,
                           norm_grads = norm_grads,
                           normalize_to_0_1 =normalize_to_0_1)

# %% [markdown]
# # 5D Gaussians, GANs

# %%
num_samples_in_cluster = 1000
dim = 5
num_gaussian_per_dim = 3
coord_limits = 2.0
sigma = 0.05
random_seed = 42
X_train = prepare_gaussians(num_samples_in_cluster = num_samples_in_cluster, 
                            dim = dim, 
                            num_gaussian_per_dim = num_gaussian_per_dim, 
                            coord_limits = coord_limits, 
                            sigma = sigma,
                            random_seed = random_seed)
n_dim = 5
n_layers_d = 3
n_layers_g = 3
n_hid_d = 512
n_hid_g = 256
n_out = 5
G_5d = Generator_fc(n_dim=n_dim, 
                    n_layers=n_layers_g,
                    n_hid=n_hid_g,
                    n_out=n_out,
                    non_linear=nn.ReLU(),
                    device=device)
D_5d = Discriminator_fc(n_in=n_dim, 
                        n_layers=n_layers_d,
                        n_hid=n_hid_d,
                        non_linear=nn.ReLU(),
                        device=device)

# %%
discriminator_regexp = os.path.join(models_5d_path, "*_discriminator.pth")
generator_regexp = os.path.join(models_5d_path, "*_generator.pth")
discriminator_name = [f for f in glob.glob(discriminator_regexp)][0]
generator_name = [f for f in glob.glob(generator_regexp)][0]
G_5d.load_state_dict(torch.load(generator_name))
D_5d.load_state_dict(torch.load(discriminator_name))
# Out:
# <All keys matched successfully>

# %%
G_5d = G_5d.to(device)
D_5d = D_5d.to(device)
for p in G_5d.parameters():  
    p.requires_grad = False
for p in D_5d.parameters():  
    p.requires_grad = False

# %%
batch_size_sample = 5000
fake_generator = G_5d.sampling(batch_size_sample).data.cpu().numpy()
proj_1 = 0
proj_2 = 1
path_to_plot_generator = None

title_generator = "Training and generated samples"
fake_label_generator = "samples by G"

plot_fake_data_projection(fake = fake_generator, 
                          X_train = X_train,
                          path_to_save = path_to_plot_generator, 
                          proj_1 = proj_1, 
                          proj_2 = proj_2,
                          title = title_generator,
                          fake_label = fake_label_generator)

# %%
n_calib_pts = 6*batch_size_sample
type_calibrator = 'iso'
normalize_to_0_1 = True
X_mh = mh_sampling(X_train, 
                   G_5d, 
                   D_5d, 
                   G_5d.device, 
                   n_calib_pts, 
                   batch_size_sample=batch_size_sample,
                   normalize_to_0_1=normalize_to_0_1,
                   type_calibrator=type_calibrator)

title_mhgan = "Training and MHGAN samples"
fake_label_mhgan = 'MHGAN samples'

plot_fake_data_projection(fake = X_mh, 
                          X_train = X_train,
                          path_to_save = path_to_plot_generator, 
                          proj_1 = proj_1, 
                          proj_2 = proj_2,
                          title = title_mhgan,
                          fake_label = fake_label_mhgan)
# Out:
# 100%|██████████| 5000/5000 [01:16<00:00, 65.42it/s]

# %%
alpha = 1.0
step_lr = 1e-2
eps_std = (2*step_lr)**0.5
n_steps = 5000
n_batches = 10

batchsize = batch_size_sample // n_batches
X_langevin, zs = langevin_sampling(G_5d, 
                                   D_5d, 
                                   alpha, 
                                   n_steps, 
                                   step_lr, 
                                   eps_std, 
                                   n=batch_size_sample, 
                                   batchsize=batchsize)

title_langevin = "Training and Langevin samples"
fake_label_langevin = f'Langevin samples, noise std = {eps_std}, lr = {step_lr}'

plot_fake_data_projection(fake = X_langevin, 
                          X_train = X_train,
                          path_to_save = path_to_plot_generator, 
                          proj_1 = proj_1, 
                          proj_2 = proj_2,
                          title = title_langevin,
                          fake_label = fake_label_langevin)
# Out:
# 100%|██████████| 10/10 [01:14<00:00,  7.43s/it]

# %%
proj_1 = 2
proj_2 = 3

plot_fake_data_projection(fake = X_langevin, 
                          X_train = X_train,
                          path_to_save = path_to_plot_generator, 
                          proj_1 = proj_1, 
                          proj_2 = proj_2,
                          title = title_langevin,
                          fake_label = fake_label_langevin)

# %%
alpha = 1.0
step_lr = 1e-3
eps_std = 1e-2
n_steps = 5000
n_batches = 10

batchsize = batch_size_sample // n_batches
X_mala, zs = mala_sampling(G_5d, 
                           D_5d, 
                           alpha, 
                           n_steps, 
                           step_lr, 
                           eps_std, 
                           n=batch_size_sample, 
                           batchsize=batchsize)

title_mala = "Training and MALA samples"
fake_label_mala = f'MALA samples, noise std = {eps_std}, lr = {step_lr}'

plot_fake_data_projection(fake = X_mala, 
                          X_train = X_train,
                          path_to_save = path_to_plot_generator, 
                          proj_1 = proj_1, 
                          proj_2 = proj_2,
                          title = title_mala,
                          fake_label = fake_label_mala)
# Out:
# 100%|██████████| 10/10 [02:52<00:00, 17.22s/it]

# %%
proj_1 = 2
proj_2 = 3

plot_fake_data_projection(fake = X_mala, 
                          X_train = X_train,
                          path_to_save = path_to_plot_generator, 
                          proj_1 = proj_1, 
                          proj_2 = proj_2,
                          title = title_mala,
                          fake_label = fake_label_mala)

# %%
alpha = 1.0
N = 2
step_lr = 1e-3
eps_std = 1e-2
n_steps = 5000
n_batches = 10

batchsize = batch_size_sample // n_batches
X_xtry_mala, zs = xtry_mala_sampling(G_5d, 
                                     D_5d, 
                                     alpha, 
                                     n_steps, 
                                     step_lr, 
                                     eps_std,
                                     N, 
                                     n=batch_size_sample, 
                                     batchsize=batchsize)
title_xtry_mala = "Training and X-Try-MALA samples"
fake_label_xtry_mala = f'X-Try-MALA samples, noise std = {eps_std}, lr = {step_lr}, N = {N}'

plot_fake_data_projection(fake = X_xtry_mala, 
                          X_train = X_train,
                          path_to_save = path_to_plot_generator, 
                          proj_1 = proj_1, 
                          proj_2 = proj_2,
                          title = title_xtry_mala,
                          fake_label = fake_label_xtry_mala)
# Out:
# 100%|██████████| 10/10 [07:52<00:00, 47.23s/it]

# %%
proj_1 = 2
proj_2 = 3

plot_fake_data_projection(fake = X_xtry_mala, 
                          X_train = X_train,
                          path_to_save = path_to_plot_generator, 
                          proj_1 = proj_1, 
                          proj_2 = proj_2,
                          title = title_xtry_mala,
                          fake_label = fake_label_xtry_mala)

# %% [markdown]
# # 2D Gaussians, true distribution

# %%
dim = 2
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

target_args = DotDict()
target_args.device = device
target_args.num_gauss = 25
n_col = 5
n_row = target_args.num_gauss // n_col
s = 1
u = torch.ones(dim)
###create points
sigma_mix = 0.05
target_args.p_gaussians = [torch.tensor(0.5)]*target_args.num_gauss
locs = [torch.tensor([(i-2)*s,(j-2)*s] + [0]* (dim - 2)).to(device) 
        for i in range(n_col) for j in range(n_row)]
target_args.locs = locs
target_args.covs = [sigma_mix*torch.eye(dim).to(device)]*target_args.num_gauss
target_args.dim = dim
target = Gaussian_mixture(target_args).log_prob

# %%
batchsize = 5000
alpha = 1.0
gamma = 1e-3
eps_std = 1e-2
n_steps = 1000
random_seed = 42
torch.manual_seed(random_seed)
np.random.seed(random_seed)
random.seed(random_seed)   

y0 = G.make_hidden(batchsize)
y0.requires_grad_(True)
y1 = G.make_hidden(batchsize)
y1.requires_grad_(True)
N = 2

y0_arr, y1_arr, weights = xtry_mala_dynamics_general(y0, y1, target, alpha, n_steps, gamma, eps_std, N)
# Out:
# 100%|██████████| 1000/1000 [01:10<00:00, 14.23it/s]

# %%
y0_last = y0_arr[-1]
#xtry_mala_achille = G(y0_last).data.cpu().numpy()
xtry_mala_achille = y0_last.data.cpu().numpy()
path_to_save = None
mode = f'X-Try-MALA'
params = f'lr = {gamma}, std noise = {eps_std}, N = {N}'
plot_fake_data_mode(xtry_mala_achille, 
                    X_train, 
                    mode, 
                    path_to_save,
                    params = params)

# %% [markdown]
# # X-Try MALA

# %%
batchsize = 5000
alpha = 1.0
step_lr = 1e-3
eps_std = 1e-2
n_steps = 500
random_seed = 42
torch.manual_seed(random_seed)
np.random.seed(random_seed)
random.seed(random_seed)   

y0 = G.make_hidden(batchsize)
y0.requires_grad_(True)
y1 = G.make_hidden(batchsize)
y1.requires_grad_(True)
N = 2

y0_arr, y1_arr, weights = xtry_mala_dynamics(y0 = y0, 
                                             y1 = y1, 
                                             gen = G, 
                                             dis = D, 
                                             alpha = alpha, 
                                             n_steps = n_steps, 
                                             step_lr = step_lr, 
                                             eps_std = eps_std, 
                                             N = N)
# Out:
# 100%|██████████| 500/500 [00:12<00:00, 39.59it/s]

# %%
weights = torch.stack(weights, dim = 0).squeeze()
first_weight = weights[:, 0].detach().cpu().numpy()
second_weight = weights[:, 1].detach().cpu().numpy()

# %%
plt.hist(x=first_weight, bins='auto')

# %%
y1_last = y1_arr[-1]
y0_last = y0_arr[-1]

# %%
x_try_mala = G(y0_last).data.cpu().numpy()
mode = f'X-Try-MALA'
params = f'lr = {step_lr}, std noise = {eps_std}'
plot_fake_data_mode(x_try_mala, X_train, mode, path_to_save, 
                    scaler = scaler,
                    params = params)

# %%
n_batches = 1
batch_size_sample = 5000
alpha = 1.0
step_lr = 1e-3
eps_std = 1e-2
N = 2
n_steps = 100
xtry_mala_sampling_visualize(G, 
                             D,
                             X_train,  
                             path_to_save,
                             alpha = alpha,
                             N = N,
                             scaler = scaler, 
                             batch_size_sample = batch_size_sample,
                             step_lr = step_lr,
                             eps_std = eps_std,
                             n_steps = n_steps,
                             n_batches = n_batches)
# Out:
# 100%|██████████| 1/1 [00:02<00:00,  2.57s/it]

# %%
n_batches = 1
batch_size_sample = 5000
alpha = 1.0
step_lr = 1e-3
eps_std = 1e-2
N = 10
n_steps = 100
xtry_mala_sampling_visualize(G, 
                             D,
                             X_train,  
                             path_to_save,
                             alpha = alpha,
                             N = N,
                             scaler = scaler, 
                             batch_size_sample = batch_size_sample,
                             step_lr = step_lr,
                             eps_std = eps_std,
                             n_steps = n_steps,
                             n_batches = n_batches)
# Out:
# 100%|██████████| 1/1 [00:08<00:00,  8.33s/it]

# %%
batchsize = 100
alpha = 1.0
step_lr = 1e-3
eps_std = 1e-2
n_steps = 100
y0 = G.make_hidden(batchsize)
y0.requires_grad_(True)
y1 = G.make_hidden(batchsize)
y1.requires_grad_(True)
N = 2

y0_arr, y1_arr, weights = xtry_mala_dynamics_v2(y0 = y0, 
                                                y1 = y1, 
                                                gen = G, 
                                                dis = D, 
                                                alpha = alpha, 
                                                n_steps = n_steps, 
                                                step_lr = step_lr, 
                                                eps_std = eps_std, 
                                                N = N)
# Out:
# 100%|██████████| 100/100 [00:30<00:00,  3.32it/s]

# %%
y1_last = y1_arr[-1]
y0_last = y0_arr[-1]

# %%
x_try_mala = G(y1_last).data.cpu().numpy()
mode = f'X-Try-MALA'
params = f'lr = {step_lr}, std noise = {eps_std}'
plot_fake_data_mode(x_try_mala, X_train, mode, path_to_save, 
                    scaler = scaler,
                    params = params)

# %%
weights = torch.stack(weights, dim = 0)

# %%
weights.shape
# Out:
# torch.Size([1000, 1, 2])

# %%
weights = weights.squeeze()
first_weight = weights[:, 0].detach().cpu().numpy()
second_weight = weights[:, 1].detach().cpu().numpy()

# %%
_, _, _ = plt.hist(x=first_weight, bins='auto')

# %%
batch_size_sample = 500
sample_fake_data(G, X_train, epoch, path_to_save, 
                 scaler = scaler,
                 batch_size_sample = batch_size_sample)

# %% [markdown]
# # MALA

# %%
for p in D.parameters():  
    p.requires_grad = False
for p in G.parameters():  
    p.requires_grad = False

# %%
batchsize = 5000
alpha = 1.0
step_lr = 1e-3
eps_std = 1e-2
n_steps = 5000
z = G.make_hidden(batchsize)
z.requires_grad_(True)
z_sp, acceptence = mala_dynamics(z, G, D, alpha, n_steps, step_lr, eps_std)

# %%
acceptence.mean()/n_steps
# Out:
# tensor(0.6859, device='cuda:0')

# %%
mala_samples = z_sp[-1]
fake_mala = G(mala_samples).data.cpu().numpy()
mode = 'MALA'
plot_fake_data_mode(fake_mala, X_train, mode, path_to_save, 
                    scaler = scaler)

# %%
mask_new_samples = (z_copy != z_sp[-1])
new_samples = z_sp[-1][mask_new_samples]
num_samples = new_samples.shape[0] // 2
fake_mala = G(new_samples.view((num_samples, 2))).data.cpu().numpy()
mode = 'MALA'
plot_fake_data_mode(fake_mala, X_train, mode, path_to_save, 
                    scaler = scaler)

# %%
batchsize = 5000
alpha = 1.0
step_lr = 1e-2
eps_std = 1e-2
n_steps = 5000
z = G.make_hidden(batchsize)
z_copy = z.clone().detach()
z.requires_grad_(True)
z_sp, acceptence = mala_dynamics(z, G, D, alpha, n_steps, step_lr, eps_std)
print(acceptence.mean().data/n_steps)
# Out:
# tensor(0.0108, device='cuda:0')

# %%
mala_samples = z_sp[-1]
fake_mala = G(mala_samples).data.cpu().numpy()
mode = 'MALA'
plot_fake_data_mode(fake_mala, X_train, mode, path_to_save, 
                    scaler = scaler)

# %%
mask_new_samples = (z_copy != z_sp[-1])
new_samples = z_sp[-1][mask_new_samples]
num_samples = new_samples.shape[0] // 2
fake_mala = G(new_samples.view((num_samples, 2))).data.cpu().numpy()
mode = 'MALA'
plot_fake_data_mode(fake_mala, X_train, mode, path_to_save, 
                    scaler = scaler)

# %%
batchsize = 5000
alpha = 1.0
step_lr = 1e-3
eps_std = 1e-3
n_steps = 5000
z = G.make_hidden(batchsize)
z_copy = z.clone().detach()
z.requires_grad_(True)
z_sp, acceptence = mala_dynamics(z, G, D, alpha, n_steps, step_lr, eps_std)
print(acceptence.mean().data/n_steps)
# Out:
# tensor(0.8191, device='cuda:0')

# %%
mala_samples = z_sp[-1]
fake_mala = G(mala_samples).data.cpu().numpy()
mode = 'MALA'
plot_fake_data_mode(fake_mala, X_train, mode, path_to_save, 
                    scaler = scaler)

# %%
mask_new_samples = (z_copy != z_sp[-1])
new_samples = z_sp[-1][mask_new_samples]
num_samples = new_samples.shape[0] // 2
fake_mala = G(new_samples.view((num_samples, 2))).data.cpu().numpy()
mode = 'MALA'
plot_fake_data_mode(fake_mala, X_train, mode, path_to_save, 
                    scaler = scaler)

# %%
batchsize = 5000
alpha = 1.0
step_lr = 1e-1
eps_std = 1e-3
n_steps = 5000
z = G.make_hidden(batchsize)
z_copy = z.clone().detach()
z.requires_grad_(True)
z_sp, acceptence = mala_dynamics(z, G, D, alpha, n_steps, step_lr, eps_std)
print(acceptence.mean().data/n_steps)
# Out:
# tensor(4.0000e-08, device='cuda:0')

# %%
mala_samples = z_sp[-1]
fake_mala = G(mala_samples).data.cpu().numpy()
mode = 'MALA'
plot_fake_data_mode(fake_mala, X_train, mode, path_to_save, 
                    scaler = scaler)

# %%
mask_new_samples = (z_copy != z_sp[-1])
new_samples = z_sp[-1][mask_new_samples]
print(new_samples.shape)
# Out:
# torch.Size([2])

# %%
new_samples
# Out:
# tensor([0.5974, 1.1048], device='cuda:0')

# %%
fake_mala = G(new_samples.view((1, 2))).data.cpu().numpy()
mode = 'MALA'
plot_fake_data_mode(fake_mala, X_train, mode, path_to_save, 
                    scaler = scaler)

# %%
batchsize = 5000
alpha = 1.0
step_lr = 1e-1
eps_std = 1e-2
n_steps = 5000
z = G.make_hidden(batchsize)
z_copy = z.clone().detach()
z.requires_grad_(True)
z_sp, acceptence = mala_dynamics(z, G, D, alpha, n_steps, step_lr, eps_std)
print(acceptence.mean().data/n_steps)
# Out:
# tensor(8.0000e-08, device='cuda:0')

# %%
mala_samples = z_sp[-1]
fake_mala = G(mala_samples).data.cpu().numpy()
mode = 'MALA'
plot_fake_data_mode(fake_mala, X_train, mode, path_to_save, 
                    scaler = scaler)

# %%
mask_new_samples
# Out:
# tensor([[False, False],
#         [False, False],
#         [False, False],
#         ...,
#         [False, False],
#         [False, False],
#         [False, False]], device='cuda:0')

# %%
z_sp[-1]
# Out:
# tensor([[-3.1241,  1.6574],
#         [ 0.4826, -0.1967],
#         [ 1.6863,  0.8296],
#         ...,
#         [ 1.0031, -0.5051],
#         [ 0.5871, -0.8596],
#         [ 1.2122,  0.5603]], device='cuda:0')

# %%
new_samples
# Out:
# tensor([ 0.9699,  2.0739,  0.4184, -1.5051], device='cuda:0')

# %%
mask_new_samples = (z_copy != z_sp[-1])
new_samples = z_sp[-1][mask_new_samples]
num_samples = new_samples.shape[0] // 2
fake_mala = G(new_samples.view((num_samples, 2))).data.cpu().numpy()
mode = 'MALA'
plot_fake_data_mode(fake_mala, X_train, mode, path_to_save, 
                    scaler = scaler)

# %%
batchsize = 5000
alpha = 1.0
step_lr = 1e-2
eps_std = 1e-4
n_steps = 5000
z = G.make_hidden(batchsize)
z_copy = z.clone().detach()
z.requires_grad_(True)
z_sp, acceptence = mala_dynamics(z, G, D, alpha, n_steps, step_lr, eps_std)
print(acceptence.mean().data/n_steps)
# Out:
# tensor(0.0004, device='cuda:0')

# %%
mala_samples = z_sp[-1]
fake_mala = G(mala_samples).data.cpu().numpy()
mode = 'MALA'
plot_fake_data_mode(fake_mala, X_train, mode, path_to_save, 
                    scaler = scaler)

# %%
mask_new_samples = (z_copy != z_sp[-1])
new_samples = z_sp[-1][mask_new_samples]
num_samples = new_samples.shape[0] // 2
fake_mala = G(new_samples.view((num_samples, 2))).data.cpu().numpy()
mode = 'MALA'
plot_fake_data_mode(fake_mala, X_train, mode, path_to_save, 
                    scaler = scaler)

# %% [markdown]
# # NUTS

# %%
def calculate_energy(params, generator, discriminator, P, normalize_to_0_1, is_dict):
    if is_dict:
        params = params['points']
    generator_points = generator(params)
    if normalize_to_0_1:
        GAN_part = -discriminator(generator_points).view(-1)
    else:
        sigmoid_GAN_part = discriminator(generator_points)
        GAN_part = -(torch.log(sigmoid_GAN_part) - \
                     torch.log1p(-sigmoid_GAN_part)).view(-1)

    prior_part = -torch.sum(P.log_prob(params), dim=-1)
    return GAN_part + prior_part

# %%
n_dim = 2
n_layers_g = 4
n_hid_g = 100
n_out = 2

n_layers_d = 4
n_hid_d = 100

#device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device = torch.device('cpu')

G = Generator_fc(n_dim=n_dim, 
                 n_layers=n_layers_g,
                 n_hid=n_hid_g,
                 n_out=n_out,
                 non_linear=nn.ReLU(),
                 device=device)
D = Discriminator_fc(n_in=n_dim, 
                     n_layers=n_layers_d,
                     n_hid=n_hid_d,
                     non_linear=nn.ReLU(),
                     device=device)

discriminator_regexp = os.path.join(models_path, "*_discriminator.pth")
generator_regexp = os.path.join(models_path, "*_generator.pth")
discriminator_name = [f for f in glob.glob(discriminator_regexp)][0]
generator_name = [f for f in glob.glob(generator_regexp)][0]

G.load_state_dict(torch.load(generator_name))
D.load_state_dict(torch.load(discriminator_name))

G = G.to(device)
D = D.to(device)

for p in D.parameters():  
    p.requires_grad = False
for p in G.parameters():  
    p.requires_grad = False

# %%
n_dim = G.n_dim
loc = torch.zeros(n_dim).to(G.device)
scale = torch.ones(n_dim).to(D.device)
normal = Normal(loc, scale)

normalize_to_0_1 = True
is_dict = True

cur_calculate_energy = partial(calculate_energy, 
                               generator = G,
                               discriminator = D,
                               P = normal,
                               normalize_to_0_1 = normalize_to_0_1,
                               is_dict = is_dict)

# %%
kernel = NUTS(potential_fn = cur_calculate_energy)

# %%
num_samples = 10
batchsize = 2

init_params = G.make_hidden(batchsize).to(device)
init_params = {'points': init_params}

# %%
cur_calculate_energy(init_params)
# Out:
# tensor([2.7370, 3.3742])

# %%
mcmc = MCMC(kernel = kernel, 
            num_samples = num_samples, 
            initial_params = init_params,
            num_chains = batchsize)
# Out:
# Warmup [1]:   0%|          | 0/20 [00:00, ?it/s]
# Warmup [2]:   0%|          | 0/20 [00:00, ?it/s]

# %%
mcmc.run()
# Out:
# [ERROR LOG CHAIN:0]Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# [ERROR LOG CHAIN:0]Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# [ERROR LOG CHAIN:0]Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# [ERROR LOG CHAIN:0]Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# [ERROR LOG CHAIN:0]Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# [ERROR LOG CHAIN:0]Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-67-a0f6be1c98b4> in <module>
# ----> 1 mcmc.run()
#
# /usr/lib/python3.9/site-packages/pyro/poutine/messenger.py in _context_wrap(context, fn, *args, **kwargs)
#      10 def _context_wrap(context, fn, *args, **kwargs):
#      11     with context:
# ---> 12         return fn(*args, **kwargs)
#      13
#      14
#
# /usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py in run(self, *args, **kwargs)
#     380             # requires_grad", which happens with `jit_compile` under PyTorch 1.7
#     381             args = [arg.detach() if torch.is_tensor(arg) else arg for arg in args]
# --> 382             for x, chain_id in self.sampler.run(*args, **kwargs):
#     383                 if num_samples[chain_id] == 0:
#     384                     num_samples[chain_id] += 1
#
# /usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py in run(self, *args, **kwargs)
#     240                 if isinstance(val, Exception):
#     241                     # Exception trace is already logged by worker.
# --> 242                     raise val
#     243                 if val is not None:
#     244                     yield val, chain_id
#
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork

# %%
device = 'cpu'
target = torch.distributions.Normal(loc=torch.tensor([10., 10.], device=device, dtype=torch.float32),
                                    scale=torch.tensor([1., 1.], device=device, dtype=torch.float32))

# %%
def potential_fn(samples):
    return -target.log_prob(samples['points']).sum(-1)

# %%
nuts = NUTS(potential_fn=potential_fn)

# %%
num_chains = 6
initial_params = {'points': torch.randn((num_chains, 2), dtype=torch.float32, device=device)}

# %%
potential_fn(initial_params)
# Out:
# tensor([ 89.7230,  88.2194,  87.5004,  99.5866, 120.7469, 113.0349])

# %%
mcmc = MCMC(kernel=nuts, num_samples=100, warmup_steps=100,
            initial_params=initial_params, num_chains=num_chains)
# Out:
# Warmup [1]:   0%|          | 0/200 [00:00, ?it/s]
# Warmup [2]:   0%|          | 0/200 [00:00, ?it/s]
# Warmup [3]:   0%|          | 0/200 [00:00, ?it/s]
# Warmup [4]:   0%|          | 0/200 [00:00, ?it/s]
# Warmup [5]:   0%|          | 0/200 [00:00, ?it/s]
# Warmup [6]:   0%|          | 0/200 [00:00, ?it/s]

# %%
mcmc.run()
# Out:
# [ERROR LOG CHAIN:0]Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# [ERROR LOG CHAIN:0]Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# [ERROR LOG CHAIN:1]Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# [ERROR LOG CHAIN:1]Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# [ERROR LOG CHAIN:2]Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# [ERROR LOG CHAIN:2]Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# [ERROR LOG CHAIN:3]Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# [ERROR LOG CHAIN:2]Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# [ERROR LOG CHAIN:3]Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# [ERROR LOG CHAIN:4]Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# [ERROR LOG CHAIN:4]Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 96, in run
#     for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, logging_hook,
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py", line 108, in _gen_samples
#     kernel.setup(warmup_steps, *args, **kwargs)
#   File "/usr/lib/python3.9/site-packages/pyro/infer/mcmc/hmc.py", line 306, in setup
#     z_grads, potential_energy = potential_grad(self.potential_fn, z)
#   File "/usr/lib/python3.9/site-packages/pyro/ops/integrator.py", line 84, in potential_grad
#     grads = grad(potential_energy, z_nodes)
#   File "/usr/lib/python3.9/site-packages/torch/autograd/__init__.py", line 202, in grad
#     return Variable._execution_engine.run_backward(
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-29-a0f6be1c98b4> in <module>
# ----> 1 mcmc.run()
#
# /usr/lib/python3.9/site-packages/pyro/poutine/messenger.py in _context_wrap(context, fn, *args, **kwargs)
#      10 def _context_wrap(context, fn, *args, **kwargs):
#      11     with context:
# ---> 12         return fn(*args, **kwargs)
#      13
#      14
#
# /usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py in run(self, *args, **kwargs)
#     380             # requires_grad", which happens with `jit_compile` under PyTorch 1.7
#     381             args = [arg.detach() if torch.is_tensor(arg) else arg for arg in args]
# --> 382             for x, chain_id in self.sampler.run(*args, **kwargs):
#     383                 if num_samples[chain_id] == 0:
#     384                     num_samples[chain_id] += 1
#
# /usr/lib/python3.9/site-packages/pyro/infer/mcmc/api.py in run(self, *args, **kwargs)
#     240                 if isinstance(val, Exception):
#     241                     # Exception trace is already logged by worker.
# --> 242                     raise val
#     243                 if val is not None:
#     244                     yield val, chain_id
#
# RuntimeError: Unable to handle autograd's threading in combination with fork-based multiprocessing. See https://github.com/pytorch/pytorch/wiki/Autograd-and-Fork
